# %% [markdown]
# ## Wind Forecasting TCN
# This is an exploration of the following paper [**Wind Power Forecasting with Deep Learning Networks: Time-Series Forecasting**](https://www.mdpi.com/2076-3417/11/21/10335) for learning purposes :)

# %%
import re, time
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
print("Tensorflow version " + tf.__version__)
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# Tensorflow version 2.18.0

# %%
try: # detect TPUs
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect() # TPU detection
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError: # detect GPUs
    strategy = tf.distribute.MirroredStrategy() # for GPU or multi-GPU machines
    strategy = tf.distribute.get_strategy() # default strategy that works on CPU and single GPU
    strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy() # for clusters of multi-GPU machines

print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# WARNING:tensorflow:From /var/folders/m0/skhn4m956412p8b4d485pzp80000gq/T/ipykernel_44972/2871771188.py:7: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/device:CPU:0',)
# INFO:tensorflow:Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:CPU:0',), communication = CommunicationImplementation.AUTO
# Number of accelerators:  1

# %%
import pandas as pd

# %%
time_series_data = pd.read_csv('T1.csv')
time_series_data["Date/Time"] = pd.to_datetime(time_series_data["Date/Time"], format='%d %m %Y %H:%M')
time_series_data.set_index('Date/Time', inplace=True)

# %%
time_series_data.head(10)
# Out:
#                      LV ActivePower (kW)  Wind Speed (m/s)  \
# Date/Time
# 2018-01-01 00:00:00           380.047791          5.311336
# 2018-01-01 00:10:00           453.769196          5.672167
# 2018-01-01 00:20:00           306.376587          5.216037
# 2018-01-01 00:30:00           419.645905          5.659674
# 2018-01-01 00:40:00           380.650696          5.577941
# 2018-01-01 00:50:00           402.391998          5.604052
# 2018-01-01 01:00:00           447.605713          5.793008
# 2018-01-01 01:10:00           387.242188          5.306050
# 2018-01-01 01:20:00           463.651215          5.584629
# 2018-01-01 01:30:00           439.725708          5.523228
#
#                      Theoretical_Power_Curve (KWh)  Wind Direction (°)
# Date/Time
# 2018-01-01 00:00:00                     416.328908          259.994904
# 2018-01-01 00:10:00                     519.917511          268.641113
# 2018-01-01 00:20:00                     390.900016          272.564789
# 2018-01-01 00:30:00                     516.127569          271.258087
# 2018-01-01 00:40:00                     491.702972          265.674286
# 2018-01-01 00:50:00                     499.436385          264.578613
# 2018-01-01 01:00:00                     557.372363          266.163605
# 2018-01-01 01:10:00                     414.898179          257.949493
# 2018-01-01 01:20:00                     493.677652          253.480698
# 2018-01-01 01:30:00                     475.706783          258.723785

# %%
time_series_data.values
# Out:
# array([[ 380.04779053,    5.31133604,  416.32890782,  259.99490356],
#        [ 453.76919556,    5.67216682,  519.91751106,  268.64111328],
#        [ 306.37658691,    5.2160368 ,  390.90001581,  272.56478882],
#        ...,
#        [2201.10693359,    8.43535805, 1788.28475526,   84.74250031],
#        [2515.6940918 ,    9.42136574, 2418.38250336,   84.2979126 ],
#        [2820.46606445,    9.97933197, 2779.18409628,   82.27462006]])

# %%
# Some data pre-processing to fill in the gaps of data using linear interpolation
time_series_data_resampled = time_series_data.resample('10min')
time_series_data_interpolated = time_series_data_resampled.interpolate(method='linear')

# %%
plt.plot(time_series_data_interpolated.loc['2018-01-01 00:00:00':'2018-01-31 23:50:00']['LV ActivePower (kW)'])

# %%
print("Frequency of the index:", time_series_data_interpolated.index.freq)
# Out:
# Frequency of the index: <10 * Minutes>

# %%
# Scale the data to between 0 and 1
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(time_series_data_interpolated)

scaled_df = pd.DataFrame(scaled_data, columns=time_series_data_interpolated.columns, index=time_series_data_interpolated.index)

# %%
plt.plot(scaled_df.loc['2018-01-01 00:00:00':'2018-12-31 23:50:00']['LV ActivePower (kW)'])

# %%
# # Baby steps: We start with a month of data and predict the last three days
first_month_scaled_data = scaled_df.loc['2018-01-01 00:00:00':'2018-1-31 23:50:00']

print(first_month_scaled_data.shape)

train_timesteps = int(60*24*28/10) # number of 10 minute timestamps in 28 days

# Train + Val
train = first_month_scaled_data[:train_timesteps]

print(train.shape)
print(val.shape)
# Out:
# (4464, 4)
# (4032, 4)
# (432, 4)

# %%
plt.plot(train['LV ActivePower (kW)'])

# %%
# Very simple vanilla time series model on TPU

lookback_window = int(7*24*60/10) # number of 10 minute intervals in 10 days
print(lookback_window)

features = train[['Wind Speed (m/s)', 'Wind Direction (°)']].values # np array
predict = train['LV ActivePower (kW)'].values # np array

val_features = first_month_scaled_data[['Wind Speed (m/s)', 'Wind Direction (°)']][train_timesteps-lookback_window+1:train_timesteps+1].values
val_predict = first_month_scaled_data['LV ActivePower (kW)'][train_timesteps-lookback_window+1:train_timesteps+1].values

print("Feature shape:" + str(features.shape))
print("Predict shape:" + str(predict.shape))

x, y = [], []

# x_val, y_val = [], []

# Sliding window time series
for i in range(lookback_window, len(train)):
  x.append(features[i - lookback_window: i])
  y.append(predict[i])

x = np.array(x)
y = np.array(y)

# x_val = np.array(x_val)
# y_val = np.array(y_val)

print("Input shape: " + str(x.shape))
print("Output shape: " + str(y.shape))

print("Input val shape: " + str(val_features.shape))
print("Output val shape: " + str(val_predict.shape))
# Out:
# 1008
# Feature shape:(4032, 2)
# Predict shape:(4032,)
# Input shape: (3024, 1008, 2)
# Output shape: (3024,)
# Input val shape: (1008, 2)
# Output val shape: (1008,)

# %%
# GPT

import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, Dropout, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Input Layer
input_layer = Input(shape=(lookback_window, 2))

# Initial Conv Layer
tensor = Conv1D(filters=16, kernel_size=11, activation='relu', padding='causal')(input_layer)

# Dilated Conv Layers
dilation_rates = [1, 2, 4, 8]
for dilation_rate in dilation_rates:
    tensor = Conv1D(filters=16, kernel_size=16, dilation_rate=dilation_rate,
               activation='relu', padding='causal')(tensor)

# Dropout Layer
tensor = Dropout(rate=0.0)(tensor)  # Assuming dropout rate is not specified

# Another Conv Layer
tensor = Conv1D(filters=16, kernel_size=16, activation='relu', padding='causal')(tensor)

tensor = Flatten()(tensor)

# Output Dense Layer
output_layer = Dense(1, activation='linear')(tensor)

# Build the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='mean_squared_error')

# Summary of the model
model.summary()
# Out:
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_17 (InputLayer)     │ (None, 1008, 2)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_78 (Conv1D)              │ (None, 1008, 16)       │           368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_79 (Conv1D)              │ (None, 1008, 16)       │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_80 (Conv1D)              │ (None, 1008, 16)       │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_81 (Conv1D)              │ (None, 1008, 16)       │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_82 (Conv1D)              │ (None, 1008, 16)       │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 1008, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_83 (Conv1D)              │ (None, 1008, 16)       │         4,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 16128)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │        16,129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,057 (144.75 KB)
#  Trainable params: 37,057 (144.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tcn import TCN
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

m = Sequential([
        Input(shape=(lookback_window, 2)),
        TCN(
        kernel_size=16,
        dilations=[1, 2, 4, 8],
        nb_stacks=4,
        ), 
        Dense(1, activation='linear')
])

# %%
m.compile('adam', 'mae')
m.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ tcn_1 (TCN)                     │ (None, 64)             │     2,035,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,035,969 (7.77 MB)
#  Trainable params: 2,035,969 (7.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print('Train...')

model.fit(x, y, epochs=10, verbose=1)
# Out:
# Train...
# Epoch 1/10
# 2024-12-11 23:00:09.269238: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [32] vs. [32,432]
# 	 [[{{function_node __inference_one_step_on_data_200063}}{{node compile_loss/mean_squared_error/sub}}]]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[89], line 3
#       1 print('Train...')
# ----> 3 model.fit(x, y, epochs=10, verbose=1)
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node compile_loss/mean_squared_error/sub defined at (most recent call last):
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/var/folders/m0/skhn4m956412p8b4d485pzp80000gq/T/ipykernel_44972/4192747958.py", line 3, in <module>
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 368, in fit
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 216, in function
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 129, in multi_step_on_iterator
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 110, in one_step_on_data
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 59, in train_step
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/trainers/trainer.py", line 399, in _compute_loss
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/trainers/trainer.py", line 367, in compute_loss
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/trainers/compile_utils.py", line 692, in __call__
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/trainers/compile_utils.py", line 701, in call
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/losses/loss.py", line 67, in __call__
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/losses/losses.py", line 33, in call
#
#   File "/Users/olivia.qin/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/losses/losses.py", line 1674, in mean_squared_error
#
# Incompatible shapes: [32] vs. [32,432]
# 	 [[{{node compile_loss/mean_squared_error/sub}}]] [Op:__inference_multi_step_on_iterator_200159]

# %%
val_features.shape
# Out:
# (311, 2)

# %%
model.predict(val_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 model.predict(val_features)
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/layers/input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional_17" is incompatible with the layer: expected shape=(None, 1008, 2), found shape=(32, 2)

# %%
p = np.clip(model.predict(val_features), 0, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 p = np.clip(model.predict(val_features), 0, 1)
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
with open('./predict_json.npy', 'rb') as f: 
    p_upload = np.load(f)

# %%
p_clipped = np.clip(p_upload, 0, 1)

# %%
plt.clf()

plt.plot(p)
plt.plot(y)
plt.title('Monthly wind power generated (kW)')
plt.legend(['predicted', 'actual'])
